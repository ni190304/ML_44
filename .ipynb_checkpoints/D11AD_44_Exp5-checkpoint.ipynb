# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv('./data/glass_data.csv')
df
# Out:
#      column_a  column_b  column_c  column_d  column_e  column_f  column_g  \
# 0           1   1.52101     13.64      4.49      1.10     71.78      0.06
# 1           2   1.51761     13.89      3.60      1.36     72.73      0.48
# 2           3   1.51618     13.53      3.55      1.54     72.99      0.39
# 3           4   1.51766     13.21      3.69      1.29     72.61      0.57
# 4           5   1.51742     13.27      3.62      1.24     73.08      0.55
# ..        ...       ...       ...       ...       ...       ...       ...
# 209       210   1.51623     14.14      0.00      2.88     72.61      0.08
# 210       211   1.51685     14.92      0.00      1.99     73.06      0.00
# 211       212   1.52065     14.36      0.00      2.02     73.42      0.00
# 212       213   1.51651     14.38      0.00      1.94     73.61      0.00
# 213       214   1.51711     14.23      0.00      2.08     73.36      0.00
#
#      column_h  column_i  column_j  column_k
# ...

# %%
df.columns
# Out:
# Index(['column_a', 'column_b', 'column_c', 'column_d', 'column_e', 'column_f',
#        'column_g', 'column_h', 'column_i', 'column_j', 'column_k'],
#       dtype='object')

# %%
df.columns = [
    "Id",
    "RI",
    "Na",
    "Mg",
    "Al",
    "Si",
    "K",
    "Ca",
    "Ba",
    "Fe",
    "Glass_type"
]

# %%
df
# Out:
#       Id       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Glass_type
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0           1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0           1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0           1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0           1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0           1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...         ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0           7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0           7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0           7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0           7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0           7
#
# [214 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          214 non-null    int64
#  1   RI          214 non-null    float64
#  2   Na          214 non-null    float64
#  3   Mg          214 non-null    float64
#  4   Al          214 non-null    float64
#  5   Si          214 non-null    float64
#  6   K           214 non-null    float64
#  7   Ca          214 non-null    float64
#  8   Ba          214 non-null    float64
#  9   Fe          214 non-null    float64
#  10  Glass_type  214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
df.isna().sum()
# Out:
# Id            0
# RI            0
# Na            0
# Mg            0
# Al            0
# Si            0
# K             0
# Ca            0
# Ba            0
# Fe            0
# Glass_type    0
# dtype: int64

# %%
df.describe()
# Out:
#                Id          RI          Na          Mg          Al          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe  Glass_type
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     0.497056    8.956963    0.175047    0.057009    2.780374
# std      0.652192    1.423153    0.497219    0.097439    2.103739
# ...

# %%
df['Glass_type'].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Glass_type, dtype: int64

# %%
len(df)
# Out:
# 214

# %%
glass_types = ['Building Windows (float processed)', 
               'Building Windows (non-float processed)', 
               'Vehicle Windows (float processed)', 
               'Vehicle Windows (non-float processed)', 
               'Containers', 
               'Tableware']
glass_counts = [df['Glass_type'].value_counts().get(1, 0),df['Glass_type'].value_counts().get(2, 0),df['Glass_type'].value_counts().get(3, 0),df['Glass_type'].value_counts().get(4, 0),df['Glass_type'].value_counts().get(5, 0),df['Glass_type'].value_counts().get(6, 0), ]

plt.figure(figsize=(8, 6))
plt.pie(glass_counts, labels=glass_types, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Glass Types')
plt.axis('equal')
plt.show()

# %%
import seaborn as sns

sns.pairplot(df, hue='Glass_type', diag_kind='hist', palette='husl')
plt.show()
# Out:
# C:\Users\Student\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Features')
plt.show()

# %%
X = df.drop('Glass_type', axis=1)
y = df['Glass_type']

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

non_linear_model = SVC(kernel='rbf', random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2)

non_linear_model.fit(X_train, y_train)
# Out:
# SVC(random_state=42)

# %%
np.array(y_test)
# Out:
# array([7, 3, 2, 1, 1, 2, 1, 5, 1, 3, 2, 3, 1, 3, 3, 5, 5, 2, 2, 1, 2, 2,
#        7, 5, 7, 1, 2, 1, 2, 7, 7, 7, 5, 1, 2, 2, 6, 1, 6, 2, 1, 5, 2],
#       dtype=int64)

# %%
y_preds = non_linear_model.predict(X_test)
y_preds
# Out:
# array([7, 2, 2, 1, 1, 2, 1, 3, 1, 2, 2, 2, 1, 2, 2, 7, 3, 2, 2, 1, 2, 2,
#        7, 3, 7, 1, 2, 1, 2, 7, 7, 7, 2, 1, 2, 2, 7, 1, 7, 2, 1, 7, 2],
#       dtype=int64)

# %%
cm = confusion_matrix(y_test, y_preds)

plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="YlOrBr", cbar=False, 
            xticklabels=['Predicted 0', 'Predicted 1'], 
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
non_linear_model.score(X_train, y_train)
# Out:
# 0.847953216374269

# %%
non_linear_model.score(X_test, y_test)
# Out:
# 0.6976744186046512

# %%
np.random.seed(42)

cv_acc = cross_val_score(non_linear_model, X, y, cv=10, scoring="accuracy")
cv_acc
# Out:
# C:\Users\Student\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:725: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# array([0.63636364, 0.81818182, 0.81818182, 0.81818182, 0.80952381,
#        0.85714286, 0.80952381, 0.80952381, 0.9047619 , 0.76190476])

# %%
np.mean(cv_acc)
# Out:
# 0.8043290043290042
